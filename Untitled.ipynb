# %%
;tar chvfz notebook.tar.gz *
# Out:
# Untitled.ipynb
# logs/
# logs/notebook/
# logs/notebook/stdout
# training/
# training/iccml/
# training/iccml/.ipynb_checkpoints/
# training/iccml/.ipynb_checkpoints/00. Motivation - Classifying fruit-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/01. ML - Representing data in a computer-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/02. Tools - Using arrays to store data-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/03. ML - Representing data with models-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/04. Tools - Functions-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/05.ML-Building-models-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/06. Tools - Adding a function parameter-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/07. ML - Model complexity-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/08. Tools - Multiple function parameters-checkpoint.ipynb
# training/iccml/.ipynb_checkpoints/09. ML - What is learning-checkpoint.ipynb
# ...
