# %% [markdown]
# # Representing data in a computer
#
# The core of data science and machine learning is **data**: we are interested in extracting knowledge from data.
#
# But how exactly do computers represent data? Let's find out exactly what an "artificial intelligence" has at its disposal to learn from.

# %% [markdown]
# ## Data is represented as arrays
#
# Let's take a look at some fruit. Using the `Images.jl` library, we can load in some images:

# %%
using Images

apple = load("data/10_100.jpg")
pixel = apple[40,60]
typeof(pixel)
# Out:
# ColorTypes.RGB4{FixedPointNumbers.Normed{UInt8,8}}

# %%
green_apple = RGB{N0f8}.(red.(apple), red.(apple), red.(apple))
# Out:
# 100×100 Array{RGB{N0f8},2}:
#  RGB{N0f8}(0.996,0.996,0.996)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.984,0.984,0.984)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.98,0.98,0.98)        RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.969,0.969,0.969)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.969,0.969,0.969)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.98,0.98,0.98)     …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.992,0.992,0.992)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  ⋮                             ⋱
#  RGB{N0f8}(0.992,0.992,0.992)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.992,0.992,0.992)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.992,0.992,0.992)  …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)        …  RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)
#  RGB{N0f8}(1.0,1.0,1.0)           RGB{N0f8}(1.0,1.0,1.0)

# %%
banana = load("data/104_100.jpg")
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                                                 ⋱
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)

# %%
a = [1,2,3,4]
b = [5,6,7,8]
c = [a b]
# Out:
# 4×2 Array{Int64,2}:
#  1  5
#  2  6
#  3  7
#  4  8

# %% [markdown]
# Here we have images of apples and bananas. We would eventually like to build a program that can automatically distinguish between the two. However, the computer doesn't "see" an apple or a banana; instead, it just sees numbers.
#
# An image is encoded in something called an **array**, which is like a container that has boxes or slots for individual pieces of data:
#
# ![attachment:array_cartoon.png](data/array_cartoon.png)
#
# An array is a bunch of numbers in connected boxes; the figure above shows a 1-dimensional array. Our images are instead 2-dimensional arrays, or matrices, of numbers, arranged something like this:

# %% [markdown]
# ![attachment:array2d.png](data/array2d.png)

# %% [markdown]
# For example, `apple` is an image, consisting of a 100x100 array of numbers:

# %%
apple[90,90]
typeof(apple[90,90])
# Out:
# ColorTypes.RGB4{FixedPointNumbers.Normed{UInt8,8}}

# %%
typeof(a)
# Out:
# UndefVarError: a not defined

# %%
b = [1
     2
    3]
# Out:
# 3-element Array{Int64,1}:
#  1
#  2
#  3

# %%
a = [1.0 2 3]
# Out:
# 1×3 Array{Float64,2}:
#  1.0  2.0  3.0

# %%
size(a)
# Out:
# (2, 3)

# %% [markdown]
# We can grab the datum stored in the box at row `i` and column `j` by *indexing* using square brackets: `[i, j]`. For example, let's get the pixel (piece of the image) in box $(40, 60)$, i.e. in the 40th row and 60th column of the image:

# %%
apple
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(0.996,1.0,0.984)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.984,1.0,0.98)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,0.988)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,0.992)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,1.0)       …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,0.996,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.992,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.988,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.984,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,1.0)      …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.996,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                              ⋱
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)

# %%
dump(typeof(apple[40, 60]))
# Out:
# ColorTypes.RGB4{FixedPointNumbers.Normed{UInt8,8}} <: ColorTypes.AbstractRGB{FixedPointNumbers.Normed{UInt8,8}}
#   r::FixedPointNumbers.Normed{UInt8,8}
#   g::FixedPointNumbers.Normed{UInt8,8}
#   b::FixedPointNumbers.Normed{UInt8,8}
#   alphadummy::FixedPointNumbers.Normed{UInt8,8}

# %%
apple[18:20,29:31]
# Out:
# 3×3 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(0.639,0.133,0.122)  …  RGB4{N0f8}(0.631,0.133,0.11)
#  RGB4{N0f8}(0.647,0.133,0.118)     RGB4{N0f8}(0.655,0.149,0.129)
#  RGB4{N0f8}(0.655,0.141,0.125)     RGB4{N0f8}(0.667,0.161,0.141)

# %% [markdown]
# We see that Julia displays a coloured box! Julia, via the `Colors.jl` package, is clever enough to display colours in a way that is useful to us humans!
#
# So, in fact, an image is a 2D array, in which each element of the array is an object (a collection of numbers) describing a coloured pixel.

# %% [markdown]
# ## Colors as numbers
#
# How, then, are these colors actually stored? Computers store colors in RGB format, that is they store a value between 0 and 1 for each of three "channels": red, green, and blue. Here, 0 means none of that color and 1 means the brightest form of that color. The overall color is a combination of those three colors.
#
# For example, we can pull out the `red` value using the function `red` applied to the color. Since internally the actual value is stored in a special format, we choose to convert it to a standard floating-point number using the `Float64` function:

# %%
apple[40,60]
# Out:
# RGB4{N0f8}(0.522,0.098,0.059)

# %%
Float64(blue(apple[40, 60]))
# Out:
# 0.058823529411764705

# %%
apple
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(0.996,1.0,0.984)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.984,1.0,0.98)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,0.988)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,0.992)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,1.0)       …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,0.996,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.992,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.988,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.984,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,1.0)      …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.996,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                              ⋱
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)

# %%
banana
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                                                 ⋱
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)  …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)  RGB4{N0f8}(1.0,1.0,1.0)     RGB4{N0f8}(1.0,1.0,1.0)

# %%
 [ mean(float.(c.(img))) for c = [red,green,blue], img = [apple,banana] ]
# Out:
# 3×2 Array{Float32,2}:
#  0.570099  0.904031
#  0.338518  0.880821
#  0.322576  0.800125

# %%
using Plots

# %%
histogram(float.(red.(apple[:])),color="red",label="apple", normalize=true, nbins=25)
histogram!(float.(red.(banana[:])),color="yellow",label="banana",normalize=true, nbins=25)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7400)" points="
# 29.1292,375.869 580.315,375.869 580.315,11.811 29.1292,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7402">
#     <rect x="29" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.7288,375.869 44.7288,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   168.535,375.869 168.535,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   292.341,375.869 292.341,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   416.148,375.869 416.148,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   539.954,375.869 539.954,11.811
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,322.173 580.315,322.173
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,268.477 580.315,268.477
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,214.781 580.315,214.781
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,161.085 580.315,161.085
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,107.39 580.315,107.39
#   "/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   29.1292,53.6938 580.315,53.6938
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.869 29.1292,11.811
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.7288,375.869 44.7288,370.408
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   168.535,375.869 168.535,370.408
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   292.341,375.869 292.341,370.408
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   416.148,375.869 416.148,370.408
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   539.954,375.869 539.954,370.408
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,375.869 37.397,375.869
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,322.173 37.397,322.173
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,268.477 37.397,268.477
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,214.781 37.397,214.781
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,161.085 37.397,161.085
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,107.39 37.397,107.39
#   "/>
# <polyline clip-path="url(#clip7400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   29.1292,53.6938 37.397,53.6938
#   "/>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 44.7288, 389.669)" x="44.7288" y="389.669">0.00</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 168.535, 389.669)" x="168.535" y="389.669">0.25</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 292.341, 389.669)" x="292.341" y="389.669">0.50</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 416.148, 389.669)" x="416.148" y="389.669">0.75</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 539.954, 389.669)" x="539.954" y="389.669">1.00</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 380.369)" x="23.1292" y="380.369">0</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 326.673)" x="23.1292" y="326.673">2</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 272.977)" x="23.1292" y="272.977">4</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 219.281)" x="23.1292" y="219.281">6</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 165.585)" x="23.1292" y="165.585">8</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 111.89)" x="23.1292" y="111.89">10</text>
# </g>
# <g clip-path="url(#clip7400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 23.1292, 58.1938)" x="23.1292" y="58.1938">12</text>
# </g>
# <polygon clip-path="url(#clip7402)" points="
# 44.7288,375.761 44.7288,375.869 69.4901,375.869 69.4901,375.761 44.7288,375.761 44.7288,375.761
#   " fill="#ff0000" fill-opacity="1"/>
# <polyline clip-path="url(#clip7402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44

# %%
apple
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(0.996,1.0,0.984)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.984,1.0,0.98)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,0.988)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,0.992)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,1.0)       …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,0.996,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.992,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.988,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.984,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,1.0)      …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.996,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                              ⋱
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)

# %%
float(red(banana[50,20]))
# Out:
# 0.61960787f0

# %%
banana[50,20]
# Out:
# RGB4{N0f8}(0.62,0.514,0.11)

# %%
pixel = apple[40, 60]

red_value   = Float64( red(pixel) )
green_value = Float64( green(pixel) )
blue_value  = Float64( blue(pixel) )

print("The RGB values are ($red_value, $green_value, $blue_value)")
# Out:
# The RGB values are (0.5215686274509804, 0.09803921568627451, 0.058823529411764705)

# %%
print("The RGB values are (red_value, green_value, blue_value)")
# Out:
# The RGB values are (red_value, green_value, blue_value)

# %% [markdown]
# Since the red value is high while the others are low, this means that at pixel `(40, 60)`, the picture of the apple is very red. If we do the same at one of the corners of the picture, we get the following:

# %%
pixel = apple[1, 1]

red_value   = Float64( red(pixel) )
green_value = Float64( green(pixel) )
blue_value  = Float64( blue(pixel) )

print("The RGB values are ($red_value, $green_value, $blue_value)")
# Out:
# The RGB values are (0.996078431372549, 1.0, 0.984313725490196)

# %%
apple
# Out:
# 100×100 Array{RGB4{N0f8},2}:
#  RGB4{N0f8}(0.996,1.0,0.984)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.984,1.0,0.98)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,0.988)        RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,0.992)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.969,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.98,1.0,1.0)       …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,0.996,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.992,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.988,1.0)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.984,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,1.0)      …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.996,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  ⋮                              ⋱
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.988)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.992,1.0,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,1.0,1.0)         RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(0.996,0.996,0.996)     RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)       RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,0.992,0.996)    …  RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)
#  RGB4{N0f8}(1.0,1.0,1.0)           RGB4{N0f8}(1.0,1.0,1.0)

# %% [markdown]
# We see that every color is bright, which corresponds to white.

# %% [markdown]
# ## Working on an image as a whole
#
# In Julia, to apply a function to the whole of an array, we place a `.` between the function name and the left parenthesis (`(`), so the following gives us the `red` value of every pixel in the image:

# %%
greenpartofapple = Float64.(green.(banana))
mean(redpartofapple)
# Out:
# 0.9040309803921569

# %%
using Plots

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
histogram(greenpartofapple[:],color=:red,label="redness in the apple")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip7800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 42.5104,375.869 580.315,375.869 580.315,11.811 42.5104,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip7802">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   90.1789,375.869 90.1789,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   208.17,375.869 208.17,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   326.162,375.869 326.162,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   444.153,375.869 444.153,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   562.144,375.869 562.144,11.811
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,321.71 580.315,321.71
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,267.55 580.315,267.55
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,213.391 580.315,213.391
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,159.232 580.315,159.232
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,105.073 580.315,105.073
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.5104,50.9139 580.315,50.9139
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 42.5104,11.811
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   90.1789,375.869 90.1789,370.408
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   208.17,375.869 208.17,370.408
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   326.162,375.869 326.162,370.408
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   444.153,375.869 444.153,370.408
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   562.144,375.869 562.144,370.408
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,375.869 50.5774,375.869
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,321.71 50.5774,321.71
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,267.55 50.5774,267.55
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,213.391 50.5774,213.391
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,159.232 50.5774,159.232
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,105.073 50.5774,105.073
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.5104,50.9139 50.5774,50.9139
#   "/>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 90.1789, 389.669)" x="90.1789" y="389.669">0.2</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 208.17, 389.669)" x="208.17" y="389.669">0.4</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 326.162, 389.669)" x="326.162" y="389.669">0.6</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 444.153, 389.669)" x="444.153" y="389.669">0.8</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 562.144, 389.669)" x="562.144" y="389.669">1.0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 380.369)" x="36.5104" y="380.369">0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 326.21)" x="36.5104" y="326.21">1000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 272.05)" x="36.5104" y="272.05">2000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 217.891)" x="36.5104" y="217.891">3000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 163.732)" x="36.5104" y="163.732">4000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 109.573)" x="36.5104" y="109.573">5000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.5104, 55.4139)" x="36.5104" y="55.4139">6000</text>
# </g>
# <polygon clip-path="url(#clip7802)" points="
# 57.7313,375.815 57.7313,375.869 60.681,375.869 60.681,375.815 57.7313,375.815 57.7313,375.815
#   " fill="#ff0000" fill-opacity="1"/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# Note that we get a 2D array (matrix) back.

# %% [markdown]
# Julia's [mathematical standard library](https://docs.julialang.org/en/stable/stdlib/math/#Mathematics-1) has many mathematical functions built in. One of them is the `mean` function, which computes the average value. If we apply this to our apple:

# %%
mean(Float64.(red.(apple)))
# Out:
# 0.5700988235294118

# %% [markdown]
# we see that the value indicates that the average amount of red in the image is a value between the amount of red in the apple and the amount of red in the white background.
#
# *Somehow we need to teach a computer to use this information about a picture to recognize that there's an apple there!*

# %% [markdown]
# ## A quick riddle
#
# Here's a quick riddle. Let's check the average value of red in the image of the banana.

# %%
mean(Float64.(red.(banana)))
# Out:
# 0.9040309803921569

# %% [markdown]
# Oh no, that's more red than our apple? This isn't a mistake and is actually true! Before you move onto the next exercise, examine the images of the apple and the banana very carefully and see if you can explain why this is expected.

# %% [markdown]
# #### Exercise 1
#
# What is the average value of blue in the banana?
#
# (To open a new box use <ESC>+b (b is for "below", what do you think a does?))

# %% [markdown]
# #### Solution
#
# We can calculate the average value of blue in the banana via

# %% [markdown]
# mean(Float64.(blue.(banana)))

# %% [markdown]
# The result is `0.8001251`.

# %% [markdown]
# #### Exercise 2
#
# Does the banana have more blue or more green?

# %% [markdown]
# #### Solution
#
# The average value of green in the banana is

# %%
mean(Float64.(green.(banana)))

# %% [markdown]
# which gives `0.8808208f0`. The banana has more green on average.
