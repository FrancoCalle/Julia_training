# %%
# Run this cell to load the graphics packages

using Plots; gr()
using Interact
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>

# %% [markdown]
# ## Adding a function parameter

# %% [markdown]
# In the last notebook, we saw an example of adding **parameters** to functions. These are values that control the behavior of a function. Let's look at that in some more detail.

# %% [markdown]
# Let's go back to our original version of the σ function:

# %%
σ(x) = 1 / (1 + exp(-x))
# Out:
# σ (generic function with 1 method)

# %% [markdown]
# Instead of working with a single function, we can work with a whole class (set) of functions that look similar but differ in the value of a **parameter**. Let's make a new function that uses the previous $\sigma$ function, but also has a parameter, $w$. Mathematically, we could write
#
# $$f_w(x) = f(x; w) = \sigma(w \, x).$$
#
# (Here, $w$ and $x$ are multiplied in the argument of $\sigma$; we could write $w \times x$ or $w * x$, or even $w \cdot x$, but usually the symbols are not written.)
#
# Mathematically speaking, we can think of $f_w$ as a different function for each different value of the parameter $w$.

# %% [markdown]
# In Julia, we write this as follows:

# %%
f(x, w) = σ(w * x)
# Out:
# f (generic function with 1 method)

# %% [markdown]
# Note that Julia just treats parameters as additional *arguments* to the function; the function `f` has two arguments, the value of `x` and the value of `w` that we want to use.

# %% [markdown]
# We can now investigate the effect of $w$ interactively. To do so, we need a way of writing in Julia "the function of one variable $x$ that we obtain when we fix the value of $w$". We write this as an "anonymous function", as we saw in the notebook on functions:
#
#     x -> f(x, w)
#
# We can read this as "the function that maps $x$ to the value of $f(x, w)$, for a value of $w$ that was previously given".

# %% [markdown]
# Now we are ready to draw the function. For each plot, we *fix* a value of the parameter $w$ and draw the resulting function as a function of $x$. However, `Interact.jl` then allows us to modify interactively the value of $w$, and plot the new function that comes out:

# %%
@manipulate for w in -2:0.01:5
    
    plot(x->f(x, w), -5, 5, ylims=(0,1), label="sigmoid")
    plot!(x->(x>0), -5,5, label="Square Wave")
end
# Out:
# Interact.Options{:SelectionSlider,Any}(7: "input-3" = 1.5 Any , "w", 1.5, "1.5", 351, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("-2.0"=>-2.0,"-1.99"=>-1.99,"-1.98"=>-1.98,"-1.97"=>-1.97,"-1.96"=>-1.96,"-1.95"=>-1.95,"-1.94"=>-1.94,"-1.93"=>-1.93,"-1.92"=>-1.92,"-1.91"=>-1.91…), Dict{Any,Any}(Pair{Any,Any}(1.19, "1.19"),Pair{Any,Any}(0.89, "0.89"),Pair{Any,Any}(4.14, "4.14"),Pair{Any,Any}(-0.8, "-0.8"),Pair{Any,Any}(1.35, "1.35"),Pair{Any,Any}(4.23, "4.23"),Pair{Any,Any}(4.56, "4.56"),Pair{Any,Any}(2.62, "2.62"),Pair{Any,Any}(3.51, "3.51"),Pair{Any,Any}(-1.22, "-1.22")…)), Any[], Any[], true, "horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2500)" points="
# 32.4745,375.869 580.315,375.869 580.315,11.811 32.4745,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2502">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   83.045,375.869 83.045,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   195.132,375.869 195.132,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.219,375.869 307.219,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   419.307,375.869 419.307,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   531.394,375.869 531.394,11.811
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,303.057 580.315,303.057
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,230.246 580.315,230.246
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,157.434 580.315,157.434
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,84.6226 580.315,84.6226
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 32.4745,11.811
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   83.045,375.869 83.045,370.408
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   195.132,375.869 195.132,370.408
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.219,375.869 307.219,370.408
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   419.307,375.869 419.307,370.408
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   531.394,375.869 531.394,370.408
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 40.6921,375.869
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,303.057 40.6921,303.057
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,230.246 40.6921,230.246
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,157.434 40.6921,157.434
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,84.6226 40.6921,84.6226
#   "/>
# <polyline clip-path="url(#clip2500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,11.811 40.6921,11.811
#   "/>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 83.045, 389.669)" x="83.045" y="389.669">-4</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 195.132, 389.669)" x="195.132" y="389.669">-2</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.219, 389.669)" x="307.219" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 419.307, 389.669)" x="419.307" y="389.669">2</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 531.394, 389.669)" x="531.394" y="389.669">4</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 380.369)" x="26.4745" y="380.369">0.0</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 307.557)" x="26.4745" y="307.557">0.2</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 234.746)" x="26.4745" y="234.746">0.4</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 161.934)" x="26.4745" y="161.934">0.6</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 89.1226)" x="26.4745" y="89.1226">0.8</text>
# </g>
# <g clip-path="url(#clip2500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 16.311)" x="26.4745" y="16.311">1.0</text>
# </g>
# <polyline clip-path="url(#clip2502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.636 83.0814,374.968 113.494,373.841 139.208,371.856 167.14,367.497 192.89,359.563 206.694,352.739 220.498,343.325 228.495,336.4 236.491,328.214
#   244.488,318.629 252.484,307.533 259.591,296.344 266.697,283.893 273.803,270.216 280.91,255.407 293.373,227.188 305.837,197.208 319.425,164.369 333.013,133.389
#   346.682,105.75 360.352,82.5609 367.908,71.7385 375.465,62.2867 383.021,54.1183 390.577,47.1229 404.957,36.6106 419.337,29.0636 434.288,23.5573 449.24,19.7681
#   461.826,17.5282 474.412,15.9115 505.144,13.6239 534.033,12.65 580.315,12.0545
#   "/>
# <polyline clip-path="url(#clip2502)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 83.0814,375.869 113.494,375.869 139.20

# %% [markdown]
# #### Exercise 1
#
# Try writing your own function that takes a parameter. Start by copying and executing
#
# ```julia
# square(x) = x^2
# ```
#
# Then use `square` to declare a new function `square_and_scale` that takes two inputs, `a` and `x` such that
#
# $$\mathrm{square\_and\_scale}(x; a) := a \cdot x^2$$

# %%
square(x) = x^2
square_and_scale(x, a) = a * x^2
# Out:
# square_and_scale (generic function with 1 method)

# %% [markdown]
# #### Solution
#
# You should have declared the following function:
#
# ```julia
# square_and_scale(x, a) = a * x^2
# ```
#
# We can write some tests as follows, using the approximate equality operator, `≈`, written as `\approx<TAB>`:
#
# ```julia
# square_and_scale(1, 1) ≈ 1
# square_and_scale(1, 2) ≈ 2
# square_and_scale(2, 1) ≈ 4
# square_and_scale(2, 2) ≈ 8
# ```

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Once you have declared `square_and_scale`, uncomment the code below and see how the parameter `a` scales the function `square` :

# %%
x = -10:10
@manipulate for a in 0:0.01:10
    plot(x, square.(x), label="x^2")
    plot!(x, square_and_scale.(x, a), ls=:dash, label="ax^2")
    ylims!(0,400)
end
# Out:
# Interact.Options{:SelectionSlider,Any}(29: "input-9" = 5.0 Any , "a", 5.0, "5.0", 501, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("0.0"=>0.0,"0.01"=>0.01,"0.02"=>0.02,"0.03"=>0.03,"0.04"=>0.04,"0.05"=>0.05,"0.06"=>0.06,"0.07"=>0.07,"0.08"=>0.08,"0.09"=>0.09…), Dict{Any,Any}(Pair{Any,Any}(9.84, "9.84"),Pair{Any,Any}(8.66, "8.66"),Pair{Any,Any}(1.19, "1.19"),Pair{Any,Any}(7.4, "7.4"),Pair{Any,Any}(7.72, "7.72"),Pair{Any,Any}(0.89, "0.89"),Pair{Any,Any}(4.14, "4.14"),Pair{Any,Any}(1.35, "1.35"),Pair{Any,Any}(4.23, "4.23"),Pair{Any,Any}(4.56, "4.56")…)), Any[], Any[], true, "horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip4900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4900)" points="
# 35.8198,375.869 580.315,375.869 580.315,11.811 35.8198,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip4902">
#     <rect x="35" y="11" width="545" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,375.869 35.8198,11.811
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.944,375.869 171.944,11.811
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   308.067,375.869 308.067,11.811
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   444.191,375.869 444.191,11.811
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,375.869 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,284.854 580.315,284.854
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,193.84 580.315,193.84
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,102.825 580.315,102.825
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.8198,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,375.869 35.8198,11.811
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,375.869 35.8198,370.408
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.944,375.869 171.944,370.408
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   308.067,375.869 308.067,370.408
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   444.191,375.869 444.191,370.408
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.869 580.315,370.408
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,375.869 43.9872,375.869
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,284.854 43.9872,284.854
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,193.84 43.9872,193.84
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,102.825 43.9872,102.825
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,11.811 43.9872,11.811
#   "/>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.8198, 389.669)" x="35.8198" y="389.669">-10</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 171.944, 389.669)" x="171.944" y="389.669">-5</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 308.067, 389.669)" x="308.067" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 444.191, 389.669)" x="444.191" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.669)" x="580.315" y="389.669">10</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8198, 380.369)" x="29.8198" y="380.369">0</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8198, 289.354)" x="29.8198" y="289.354">100</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8198, 198.34)" x="29.8198" y="198.34">200</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8198, 107.325)" x="29.8198" y="107.325">300</text>
# </g>
# <g clip-path="url(#clip4900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8198, 16.311)" x="29.8198" y="16.311">400</text>
# </g>
# <polyline clip-path="url(#clip4902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8198,284.854 63.0445,302.147 90.2693,317.619 117.494,331.272 144.719,343.103 171.944,353.115 199.168,361.306 226.393,367.677 253.618,372.228 280.843,374.959
#   308.067,375.869 335.292,374.959 362.517,372.228 389.742,367.677 416.966,361.306 444.191,353.115 471.416,343.103 498.641,331.272 525.865,317.619 553.09,302.147
#   580.315,284.854
#   "/>
# <polyline clip-path="url(#clip4902)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" stroke-dasharray="8, 5" points="
#   35.8198,-79.2034 63.0445,7.2603 90.2693,84.6226 117.494,152.883 144.719,212.043 171.944,262.101 199.168,303.057 226.393,334.912 253.618,357.666 280.843,371.318
#   308.067,375.869 335.292,371.318 362.517,357.666 389.742,334.912 416.966,303.057 444.191,262.101 471.416,212.043 498.641,152.883 525.865,84.6226 553.09,7.2603
#   580.315,-79.2034
#   "/>
# <polygon clip-path="url(#clip4900)" points="
# 477.273,78.051 562.315,78.051 562.315,32.691 477.273,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip4900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   477.273,78.051 562.315,78.051 562.315,32.691 477.273,32.691 477.273,78.051
#   "/>
# <polyline clip-path="url(#clip4900)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# ## Fitting a function to data

# %% [markdown]
# As we saw in the previous notebook, what we would like to do is use the fact that we now have a parameter in our function in order to do something useful! Namely, we want to model data with it.

# %% [markdown]
# So suppose that we are given a single data point $(x_0, y_0) = (2, 0.8)$. We can try to "fit" the function $f_w$ by adjusting the parameter $w$ until the function passes through the data.
#
# **Game**: Move the slider until the graph of the function hits the data point. Which value of $w$ does that correspond to?

# %%
x0, y0 = 2, 0.8

@manipulate for w in -2:0.01:2
    plot(x->f(x, w), -5, 5, ylims=(0, 1), label="f")
    scatter!([x0], [y0], label="data")
end
# Out:
# Interact.Options{:SelectionSlider,Any}(15: "input-5" = 0.0 Any , "w", 0.0, "0.0", 201, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("-2.0"=>-2.0,"-1.99"=>-1.99,"-1.98"=>-1.98,"-1.97"=>-1.97,"-1.96"=>-1.96,"-1.95"=>-1.95,"-1.94"=>-1.94,"-1.93"=>-1.93,"-1.92"=>-1.92,"-1.91"=>-1.91…), Dict{Any,Any}(Pair{Any,Any}(-0.92, "-0.92"),Pair{Any,Any}(1.2, "1.2"),Pair{Any,Any}(1.68, "1.68"),Pair{Any,Any}(-0.22, "-0.22"),Pair{Any,Any}(-1.78, "-1.78"),Pair{Any,Any}(1.19, "1.19"),Pair{Any,Any}(-1.23, "-1.23"),Pair{Any,Any}(0.22, "0.22"),Pair{Any,Any}(-1.16, "-1.16"),Pair{Any,Any}(0.2, "0.2")…)), Any[], Any[], true, "horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 32.4745,375.869 580.315,375.869 580.315,11.811 32.4745,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3702">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   95.6874,375.869 95.6874,11.811
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   201.43,375.869 201.43,11.811
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.173,375.869 307.173,11.811
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   412.916,375.869 412.916,11.811
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   518.658,375.869 518.658,11.811
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,303.057 580.315,303.057
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,230.246 580.315,230.246
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,157.434 580.315,157.434
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,84.6226 580.315,84.6226
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,11.811 580.315,11.811
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 32.4745,11.811
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   95.6874,375.869 95.6874,370.408
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   201.43,375.869 201.43,370.408
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.173,375.869 307.173,370.408
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   412.916,375.869 412.916,370.408
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   518.658,375.869 518.658,370.408
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 40.6921,375.869
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,303.057 40.6921,303.057
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,230.246 40.6921,230.246
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,157.434 40.6921,157.434
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,84.6226 40.6921,84.6226
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,11.811 40.6921,11.811
#   "/>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 95.6874, 389.669)" x="95.6874" y="389.669">-4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 201.43, 389.669)" x="201.43" y="389.669">-2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.173, 389.669)" x="307.173" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 412.916, 389.669)" x="412.916" y="389.669">2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 518.658, 389.669)" x="518.658" y="389.669">4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 380.369)" x="26.4745" y="380.369">0.0</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 307.557)" x="26.4745" y="307.557">0.2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 234.746)" x="26.4745" y="234.746">0.4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 161.934)" x="26.4745" y="161.934">0.6</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 89.1226)" x="26.4745" y="89.1226">0.8</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 16.311)" x="26.4745" y="16.311">1.0</text>
# </g>
# <polyline clip-path="url(#clip3702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9794,193.84 95.7218,193.84 124.413,193.84 148.671,193.84 175.022,193.84 199.315,193.84 225.36,193.84 255.536,193.84 282.352,193.84 305.868,193.84
#   331.507,193.84 357.297,193.84 385.812,193.84 412.944,193.84 441.154,193.84 464.901,193.84 493.894,193.84 521.147,193.84 564.81,193.84
#   "/>
# <circle clip-path="url(#clip3702)" style="fill:#000000; stroke:none; fill-opacity:1" cx="412.916" cy="84.6226" r="4"/>
# <circle clip-path="url(#clip3702)" style="fill:#e26f46; stroke:none; fill-opacity:1" cx="412.916" cy="84.6226" r="3"/>
# <polygon clip-path="url(#clip3700)" points="
# 478.898,78.051 562.315,78.051 562.315,32.691 478.898,32.691
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; st

# %% [markdown]
# ## Quantifying how far we are from the goal: the *loss function*

# %% [markdown]
# We can see visually when the graph of the function passes through the data point. But the goal is to be able to automate this process so that the computer can do it unaided.
#
# So we will need a more precise way of deciding and quantifying (i.e. measuring with a number) *how far away we are from the goal*; here, the goal means hitting the data point with the function.

# %% [markdown]
# #### Exercise 3
#
# Can you think of a way of measuring how far away our function is from the data point?

# %% [markdown]
# ### Defining the loss function

# %% [markdown]
# We need to measure how far away the curve is from the data point when we choose a particular value of $w$.
# One way to do this is by finding the vertical distance $d$ from the curve to the data point.
#
# Instead of just taking the distance, it is common to take the *square* of the distance, $d^2$.
#
# Since we are taking the vertical distance, we need the distance at the given value of $x_0$ where the data point lies. For a given value of the parameter $w$, the height of the point on the curve with that value of $x_0$ is $f(x_0, w)$.
#
# So we take
# $$d := y_0 - f(x_0, w)$$
#
# and
# $$d^2 = [y_0 - f(x_0, w)]^2.$$
#
# This is our measure of distance. It will change when $w$ changes -- in other words, it is itself a *function of $w$*; we will denote this function by $L(w)$, and call it the **loss function**:
#
# $$L(w) := [y_0 - f(x_0, w)]^2.$$
#
# So the goal is to find the value $w^*$ of $w$ where the loss function is *least*; in other words, we need to *minimize* the loss function!
#
# (Another name for a loss function is a *cost function*.)

# %% [markdown]
# #### Exercise 4
#
# (a) Define the loss function `L(w)` in Julia.
#
# (b) Draw the data point and the function `x -> f(x, w)`. Also draw a vertical line from the data point to the function `x -> f(x, w)`.
#
# (c) Make the plot interactive.
#
# (d) Add as the plot title the value of the loss function for the current value of $w$.
#
# (e) Use the slider to find the value $w^*$ of $w$ for which the loss function reaches its minimum value. What is $w^*$? What is the value of the loss function there, $L(w^*)$?

# %% [markdown]
# #### Solution

# %% [markdown]
# (a) We have data

# %%
x0, y0 = 2, 0.8
# Out:
# (2, 0.8)

# %% [markdown]
# We define the loss function as follows:

# %%
L(w) = (y0 - f(x0, w))^2
# Out:
# L (generic function with 1 method)

# %% [markdown]
# (b-d): The visualization can be written as follows

# %%
@manipulate for w in -2:0.01:2
    
    plot(x->f(x, w), -5, 5, ylims=(0, 1), label="f_w", lw=3)  # function

    scatter!([x0], [y0], label="data")
    plot!([x0, x0], [y0, f(x0, w)], label="loss")  # vertical line

    title!("L(w) = $(round(L(w), 5))")

end
# Out:
# Interact.Options{:SelectionSlider,Any}(33: "input-10" = 0.0 Any , "w", 0.0, "0.0", 201, Interact.OptionDict(DataStructures.OrderedDict{Any,Any}("-2.0"=>-2.0,"-1.99"=>-1.99,"-1.98"=>-1.98,"-1.97"=>-1.97,"-1.96"=>-1.96,"-1.95"=>-1.95,"-1.94"=>-1.94,"-1.93"=>-1.93,"-1.92"=>-1.92,"-1.91"=>-1.91…), Dict{Any,Any}(Pair{Any,Any}(-0.92, "-0.92"),Pair{Any,Any}(1.2, "1.2"),Pair{Any,Any}(1.68, "1.68"),Pair{Any,Any}(-0.22, "-0.22"),Pair{Any,Any}(-1.78, "-1.78"),Pair{Any,Any}(1.19, "1.19"),Pair{Any,Any}(-1.23, "-1.23"),Pair{Any,Any}(0.22, "0.22"),Pair{Any,Any}(-1.16, "-1.16"),Pair{Any,Any}(0.2, "0.2")…)), Any[], Any[], true, "horizontal")
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip8300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8300)" points="
# 32.4745,375.869 580.315,375.869 580.315,31.4961 32.4745,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip8302">
#     <rect x="32" y="31" width="549" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   95.6874,375.869 95.6874,31.4961
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   201.43,375.869 201.43,31.4961
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   307.173,375.869 307.173,31.4961
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   412.916,375.869 412.916,31.4961
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   518.658,375.869 518.658,31.4961
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,306.994 580.315,306.994
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,238.12 580.315,238.12
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,169.245 580.315,169.245
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,100.371 580.315,100.371
#   "/>
# <polyline clip-path="url(#clip8302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 32.4745,31.4961
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   95.6874,375.869 95.6874,370.703
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   201.43,375.869 201.43,370.703
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   307.173,375.869 307.173,370.703
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   412.916,375.869 412.916,370.703
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   518.658,375.869 518.658,370.703
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 40.6921,375.869
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,306.994 40.6921,306.994
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,238.12 40.6921,238.12
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,169.245 40.6921,169.245
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,100.371 40.6921,100.371
#   "/>
# <polyline clip-path="url(#clip8300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,31.4961 40.6921,31.4961
#   "/>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 95.6874, 389.669)" x="95.6874" y="389.669">-4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 201.43, 389.669)" x="201.43" y="389.669">-2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 307.173, 389.669)" x="307.173" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 412.916, 389.669)" x="412.916" y="389.669">2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 518.658, 389.669)" x="518.658" y="389.669">4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 380.369)" x="26.4745" y="380.369">0.0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 311.494)" x="26.4745" y="311.494">0.2</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 242.62)" x="26.4745" y="242.62">0.4</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 173.745)" x="26.4745" y="173.745">0.6</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 104.871)" x="26.4745" y="104.871">0.8</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 35.9961)" x="26.4745" y="35.9961">1.0</text>
# </g>
# <g clip-path="url(#clip8300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 306.395, 18)" x="306.395" y="18">L(w) = 0.09</text>
# </g>
# <polyline clip-path="url(#clip8302)" style="stroke:#009af9; stroke-width:3; stroke-opacity:1; fill:none" points="
#   47.9794,203.682 95.7218,203.682 124.413,203.682 148.671,203.682 175.022,203.682 199.315,203.682 225.36,203.682 255.536,203.682 282.352,203.682 305.868,203.682
#   331.507,203.682 357.297,203.682 385.812,203.682 412.944,203.682 441.154,203.682 464.901,203.682 493.894,203.682 521.147,203.682 564.81,203.682
#   "/>
# <circle clip-path="url(#clip8302)" style="fill:#000000; stroke:none; fill-opacity:1" cx="412.916" cy="100.371" r="4"/>
# <circle clip-path="url(#clip8302)" style="fill:#e26f46;

# %% [markdown]
# ## What does the loss function look like?

# %% [markdown]
# The loss function $L(w)$ tells us how far away the function $f_w$ is from the data when the parameter value is $w$, represented visually as the vertical line in the previous plot. When the data are fixed, this is a function only of the parameter $w$. What does this function look like as a function of $w$? Let's draw it!

# %% [markdown]
# #### Exercise 5
#
# Draw the function $L(w)$ as a function of $w$.

# %% [markdown]
# #### Solution

# %%
plot(L, -3, 3, xlabel="w", ylabel="L(w)", ylims=(0, 0.7), label="L")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1900)" points="
# 48.2225,360.121 580.315,360.121 580.315,11.811 48.2225,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1902">
#     <rect x="48" y="11" width="533" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   133.628,360.121 133.628,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   224.349,360.121 224.349,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.07,360.121 315.07,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   405.791,360.121 405.791,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   496.512,360.121 496.512,11.811
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,360.121 580.315,360.121
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,310.362 580.315,310.362
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,260.604 580.315,260.604
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,210.845 580.315,210.845
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,161.087 580.315,161.087
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,111.328 580.315,111.328
#   "/>
# <polyline clip-path="url(#clip1902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,61.5695 580.315,61.5695
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 580.315,360.121
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 48.2225,11.811
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   133.628,360.121 133.628,354.896
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   224.349,360.121 224.349,354.896
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.07,360.121 315.07,354.896
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   405.791,360.121 405.791,354.896
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   496.512,360.121 496.512,354.896
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 56.2039,360.121
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,310.362 56.2039,310.362
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,260.604 56.2039,260.604
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,210.845 56.2039,210.845
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,161.087 56.2039,161.087
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,111.328 56.2039,111.328
#   "/>
# <polyline clip-path="url(#clip1900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,61.5695 56.2039,61.5695
#   "/>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 133.628, 373.921)" x="133.628" y="373.921">-2</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 224.349, 373.921)" x="224.349" y="373.921">-1</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.07, 373.921)" x="315.07" y="373.921">0</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 405.791, 373.921)" x="405.791" y="373.921">1</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 496.512, 373.921)" x="496.512" y="373.921">2</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 364.621)" x="42.2225" y="364.621">0.0</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 314.862)" x="42.2225" y="314.862">0.1</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 265.104)" x="42.2225" y="265.104">0.2</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 215.345)" x="42.2225" y="215.345">0.3</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 165.587)" x="42.2225" y="165.587">0.4</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 115.828)" x="42.2225" y="115.828">0.5</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 66.0695)" x="42.2225" y="66.0695">0.6</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 314.269, 397.6)" x="314.269" y="397.6">w</text>
# </g>
# <g clip-path="url(#clip1900)">
# <text style="fill:#0000

# %% [markdown]
# ### Features of the loss function

# %% [markdown]
# This graph quantifies how far we are from the data point for a given value of $w$.
# What features can we see from the graph?
#
# Firstly, we see that $L(w)$ is always bigger than $0$, for any value of $w$. This is because we want $L$ to be some kind of measure of *distance*, and distances cannot be negative.
#
# Secondly, we see that there is a special value $w^*$ of $w$ where the function $L$ reaches its minimum value. In this particular case, it actually reaches all the way down to $0$!
# This means that the original function $f$ (the one we manipulated above) passes exactly through the data point $(x_0, y_0)$.

# %% [markdown]
# #### Exercise 6
#
# Draw a zoomed-in version of the graph to find the place $w^*$ where the function hits $0$ more precisely.

# %% [markdown]
# ### A different way of defining the loss function

# %% [markdown]
# **Why did we use such a complicated function $L$ with those squares inside?** We could instead just have used the absolute distance, instead of the distance squared, using the *absolute value* function, written mathematically as $| \cdot |$, and in Julia as `abs`.

# %% [markdown]
# #### Exercise 7
#
# Define a new loss function, `L_abs`, using the absolute value, and see what it looks like.

# %% [markdown]
# #### Solution

# %%
L_abs(w) = abs(y0 - f(x0, w))

plot(L_abs, -3, 3, xlabel="w", ylabel="L_abs(w)", ylims=(0, 0.7), label="L_abs")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2100)" points="
# 48.2225,360.121 580.315,360.121 580.315,11.811 48.2225,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2102">
#     <rect x="48" y="11" width="533" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   133.628,360.121 133.628,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   224.349,360.121 224.349,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   315.07,360.121 315.07,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   405.791,360.121 405.791,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   496.512,360.121 496.512,11.811
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,360.121 580.315,360.121
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,310.362 580.315,310.362
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,260.604 580.315,260.604
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,210.845 580.315,210.845
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,161.087 580.315,161.087
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,111.328 580.315,111.328
#   "/>
# <polyline clip-path="url(#clip2102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.2225,61.5695 580.315,61.5695
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 580.315,360.121
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 48.2225,11.811
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   133.628,360.121 133.628,354.896
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   224.349,360.121 224.349,354.896
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   315.07,360.121 315.07,354.896
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   405.791,360.121 405.791,354.896
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   496.512,360.121 496.512,354.896
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,360.121 56.2039,360.121
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,310.362 56.2039,310.362
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,260.604 56.2039,260.604
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,210.845 56.2039,210.845
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,161.087 56.2039,161.087
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,111.328 56.2039,111.328
#   "/>
# <polyline clip-path="url(#clip2100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.2225,61.5695 56.2039,61.5695
#   "/>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 133.628, 373.921)" x="133.628" y="373.921">-2</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 224.349, 373.921)" x="224.349" y="373.921">-1</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 315.07, 373.921)" x="315.07" y="373.921">0</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 405.791, 373.921)" x="405.791" y="373.921">1</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 496.512, 373.921)" x="496.512" y="373.921">2</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 364.621)" x="42.2225" y="364.621">0.0</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 314.862)" x="42.2225" y="314.862">0.1</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 265.104)" x="42.2225" y="265.104">0.2</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 215.345)" x="42.2225" y="215.345">0.3</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 165.587)" x="42.2225" y="165.587">0.4</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 115.828)" x="42.2225" y="115.828">0.5</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.2225, 66.0695)" x="42.2225" y="66.0695">0.6</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 314.269, 397.6)" x="314.269" y="397.6">w</text>
# </g>
# <g clip-path="url(#clip2100)">
# <text style="fill:#0000

# %% [markdown]
# Now we see why it was previously generally preferred to use squares: using the absolute value gives a cost function that is *not smooth*. This makes it difficult to use methods from calculus to find the minimum. Nonetheless, using non-smooth functions is very common in machine learning nowadays.
